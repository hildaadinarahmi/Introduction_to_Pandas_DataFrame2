# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #From Dictionary

# %%
dict_1 = {"country": ["Brazil", "Russia","India", "China", "South Africa"],
          "capital": ["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
          "area": [8.516, 17.10, 3.286, 1.221, 345.678],
          "population": [200.4, 143.5, 1252, 1357, 52.97]}

# %%
dict_1.keys()
# Out:
# dict_keys(['country', 'capital', 'area', 'population'])

# %%
dict_1.values()
# Out:
# dict_values([['Brazil', 'Russia', 'India', 'China', 'South Africa'], ['Brasilia', 'Moscow', 'New Delhi', 'Beijing', 'Pretoria'], [8.516, 17.1, 3.286, 1.221, 345.678], [200.4, 143.5, 1252, 1357, 52.97]])

# %%
import pandas as pd
df = pd.DataFrame(dict_1)
df
# Out:
#         country    capital     area  population
# 0        Brazil   Brasilia    8.516      200.40
# 1        Russia     Moscow   17.100      143.50
# 2         India  New Delhi    3.286     1252.00
# 3         China    Beijing    1.221     1357.00
# 4  South Africa   Pretoria  345.678       52.97

# %% [markdown]
# #From CSV / Excel File

# %%
from google.colab import drive
drive.mount('/drive', force_remount=True)
df_dataaa = pd.read_csv('/drive/MyDrive/data_coding_2.csv')
df_dataaa
# Out:
# Mounted at /drive
#    Genotipe Rumah Kaca     Lahan
# 0        G1   5.55 abc  6.72 bcd
# 1        G2    4.40 cd   7.04 bc
# 2        G3    5.85 ab   6.20 cd
# 3        G4  5.42 abcd   6.00 cd
# 4        G5  5.36 abcd  6.78 bcd
# 5        G6   5.00 bcd  6.86 bcd
# 6        G7  5.31 abcd  6.72 bcd
# 7        G8  5.37 abcd    5.64 d
# 8        G9   4.95 bcd   7.71 ab
# 9       G10  5.29 abcd   8.40 AM
# 10      G11      6.37a   7.05 bc
# 11      G12     4.13 d   6.33 cd

# %% [markdown]
# #DataFrame Selection

# %% [markdown]
# ##Column Selection for a Single Column

# %%
#Show as a series
df_dataaa['Genotipe']
# Out:
# 0      G1
# 1      G2
# 2      G3
# 3      G4
# 4      G5
# 5      G6
# 6      G7
# 7      G8
# 8      G9
# 9     G10
# 10    G11
# 11    G12
# Name: Genotipe, dtype: object

# %%
dataaa_df.Genotipe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0c4df4c70278> in <cell line: 1>()
# ----> 1 dataaa_df.Genotipe
#
# NameError: name 'dataaa_df' is not defined
